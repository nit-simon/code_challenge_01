# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup #as soup
import time
import json

from pathlib import Path  
import os

# %% [markdown]
# versions of the core libraries used
# - pandas version: 1.0.1
#
# - BeautifulSoup version: 4.8.2
#
# - requests version: 2.22.0
#
# - python version: 3.7.3

# %%
# tested only on windows, fetch the username folder, assist in saving location
# first = len("c:\\users\\")
# print(os.path.abspath(os.getcwd()))
# pwd = os.path.abspath(os.getcwd())
# second = pwd[first:len(pwd)]
# third = second.find("\\")
# pc_username_folder = second[0:third]
# print("username: "+ pc_username_folder)

# save_loc =fr'C:\Users\{pc_username_folder}\Desktop\pharma_ida.csv'

# %%
#manually type save location
save_loc =fr'C:\Users\rsimon\Desktop\pharma_ida.csv'

# %%
#This URL is the page you actually want to pull down with requests.
initial_page = 'https://idbop.mylicense.com/verification/Search.aspx'
searchPage = initial_page

# %%
# format the fetch list into  columns.
def list_format(list_name, step):
    return [list_name[i::step] for i in range(step)]
#print(list_format(data,4))

# %%
#load the next/selected page page
def fetch_next_page(page):
    payload_next_page = {
    "CurrentPageIndex":page,
    "__EVENTTARGET":"datagrid_results$_ctl44$_ctl1",
    "__EVENTARGUMENT":"",
    "__VIEWSTATEGENERATOR":viewStateGenerator,
    "__VIEWSTATE":viewState,
    "__EVENTVALIDATION":eventValidation}
    nextpage="https://idbop.mylicense.com/verification/SearchResults.aspx"
    result_np=req_sess.post(nextpage,headers=headers1,data=payload_next_page)
    soup1=BeautifulSoup(result_np.content, 'html.parser')
    td_as_base1 = soup1.find_all('td') 
    data2 = []
    for cell in td_as_base1:
            if cell.text=="":
                #print("empty string skipped")
                continue
            #if cell.text.startswith('\n'):
            if '\\' in  r"%r" % cell.text:
                #print("slash skipped")
                continue
            insertdata = cell.text.strip()
            data2.append(insertdata)
    return data2 ,soup1

# %%
# fetch the number of pages of the search
def count_pages():
    pagination=BeautifulSoup(result.content, 'html.parser')
    paginationtags = pagination.find_all('a') # all trs
    pages = [tag.text.strip() for tag in paginationtags if tag.text.isnumeric()]
    return pages

# %%
# extra texts that appear on the list 
def remove_these(thisList):
    try:
        thisList.remove("Search")
        thisList.remove("Search Results")
        print("Removed exess texts")
    except:
        print("keywords removed/not present")

# %%
############# SEQUENCE 1 - the initial page needs to be loaded first to acquire the viewstate to be used in the search page, then the pagination

# %%
# initiaate the search
print("Loading the initial page")
req_sess=requests.Session()
r=req_sess.get(initial_page)
time.sleep(5)
soup=BeautifulSoup(r.content, 'html.parser')
# Out:
# Loading the initial page

# %%
# eventTarget=soup.find(id="__EVENTTARGET")['value']
#eventArguement=soup.find(id="__EVENTARGUMENT")['value']
viewState=soup.find(id="__VIEWSTATE")['value']
viewStateGenerator=soup.find(id="__VIEWSTATEGENERATOR")['value']
eventValidation=soup.find(id="__EVENTVALIDATION")['value']

# %%
# # for testing
# license_type_name = "Pharmacist"
# lastName ="L*"

# %%
### search fields , Please uncomment after testing

lastName = input("Enter Last Name")
first_name  = input('Enter First Name')
license_type_name =input("Enter License Type")
last_name  = input('Enter Last Name')
addr_city  = input('Enter City')
license_no  = input('Enter license no')
addr_state  = input('Enter State')
license_status_name  = input('Enter license status')
addr_county  = input('Enter Country')
addr_zipcode  = input('Enter Zip')

# %%
payload = {
    "__EVENTTARGET":"",
    "__EVENTARGUMENT":"",
    "__LASTFOCUS":"",
    "__VIEWSTATEGENERATOR":viewStateGenerator,
    "__VIEWSTATE":viewState,
    "__EVENTVALIDATION":eventValidation,
    "t_web_lookup__first_name":"",
    "t_web_lookup__license_type_name":license_type_name,
    "t_web_lookup__last_name":lastName,
    "t_web_lookup__addr_city":"",
    "t_web_lookup__license_no":"",
    "t_web_lookup__addr_state":"",
    "t_web_lookup__license_status_name":"",
    "t_web_lookup__addr_county":"",
    "t_web_lookup__addr_zipcode":"",
    "sch_button":"Search"
}

# %%
# request header for  inital request page
headers1 = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding':'gzip, deflate, br',
    'Connection':'keep-alive',
    'Cache-Control':'max-age=0',
    'Content-Length': '2853',
    'Content-Type':'application/x-www-form-urlencoded; charset=UTF-8',
    'Host':'idbop.mylicense.com',
    'Origin':'https://idbop.mylicense.com',
    'Referer': 'https://idbop.mylicense.com/verification/Search.aspx',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54',
    'X-Requested-With':'XMLHttpRequest'
}

# %%
#request header for the next page
headers2 = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding':'gzip, deflate, br',
    'Connection':'keep-alive',
    'Cache-Control':'max-age=0',
    'Content-Length': '2853',
    'Content-Type':'application/x-www-form-urlencoded; charset=UTF-8',
    'Host':'idbop.mylicense.com',
    'Origin':'https://idbop.mylicense.com',
    'Referer': 'https://idbop.mylicense.com/verification/SearchResults.aspx',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54',
    'X-Requested-With':'XMLHttpRequest'
}

# %%
print("submitting inital requet to page")
result=req_sess.post(searchPage,headers=headers1,data=payload)
# Out:
# submitting inital requet to page

# %%
# searchPage

# %%
# for fetching the page count
soup=BeautifulSoup(result.text, 'html.parser')

# %%
# get all the links per person
def get_all_links(soup):
    #soup=BeautifulSoup(result.text, 'html.parser')
    tds = soup.find_all('td')
    atagList=[]
    for atags in tds:
        atag = atags.find('a')
        if atag==[]:
            continue
        if atag==None:
            continue
        if not atag.has_attr('target'):    #add this line
            continue
        if not atag['target']=='_blank':   #add this line
            continue
        if len(atag['href'])<43:           #add this line
            continue
        atagList.append(atag)    
    ##list of names only
    
    #atagList_reduce=atagList[6:86:1] # remove this line  ##########################
    
    ##remove the duplicates
    #reduced_atag = atagList_reduce[::2] -- change variable name as below ##################
    reduced_atag = atagList[::2] 
    print("hrefs fethed: "+ str(len(reduced_atag)))
    #href = reduced_atag[0].find_all('id')
    href_tags = []
    for hr in reduced_atag:
        hreftag =hr.get('href')
        href_tags.append(hreftag)
        #print(href_tags)
    return href_tags

# %%
# get full data of the person page
def get_person_data(href_tag):
    resultOnly = href_tag[20::] 
    person_req_link = "https://idbop.mylicense.com/verification/"
    person_req_get_request_link = person_req_link+href_tag
    person=req_sess.get(person_req_get_request_link,headers=headers2,data=resultOnly)
    time.sleep(1)

    #working code v1
    person_page=BeautifulSoup(person.content, 'html.parser')
    table  =person_page.find_all('table')


    person_data = []
    for td in table[4]:
        try:
            row = td.find('td').text.strip()
            #print(row)
            person_data.append(row)
        except:
            continue

    person_data1 = []
    tds2 = table[4].find_all('td')
    for td in tds2:
        for tr in td:
            try:
                trdata= tr.text.strip()
                person_data1.append(trdata)
            except:
                continue

    dataSet2 = []
    for td in table[8]:
        for tr in td:
            try:
                trdata= tr.text.strip()
                dataSet2.append(trdata)
            except:
                continue

    dataSet1 = person_data1[9:15:]

    person_data1 = []
    tds2 = table[4].find_all('td')
    for td in tds2:
        for tr in td:
            try:
                trdata= tr.text.strip()
                person_data1.append(trdata)
            except:
                continue

    final_dataset = dataSet1+dataSet2

    person_info = list_format(final_dataset, 2)

    df1 = pd.DataFrame(person_info)
    header_row = df1.iloc[0]
    df2 = pd.DataFrame(df1.values[1:], columns=header_row)

    return df2

# %%
#query model
#https://idbop.mylicense.com/verification/Details.aspx?result=7fabb069-2284-4244-ac9f-115002f9da12

# %%
# For page 1
persons_on_this_page = get_all_links(soup)
# Out:
# hrefs fethed: 40

# %%
#fetch page 1
all_person =[]
for person in persons_on_this_page:
    print(person)
    each_person = get_person_data(person)
    time.sleep(3)
    all_person.append(each_person)
# Out:
# Details.aspx?result=10448fb5-5850-47a4-890a-182f3dd80008
# Details.aspx?result=811ba51b-c721-411e-925e-52f201e106a7
# Details.aspx?result=d47fef5e-8b7f-43e9-a858-9437b769a6f8
# Details.aspx?result=8a7126d1-ca77-46b8-a880-d73c1c26fb70
# Details.aspx?result=dab6f4f9-fedf-4e9c-afcc-5d2540330fec
# Details.aspx?result=6d085d4a-aa4e-46ed-8c66-203b10afe942
# Details.aspx?result=a352da93-09e7-4799-be19-85835eaddfec
# Details.aspx?result=68b2b8a4-39c8-4841-8963-cb3fc7e4ac99
# Details.aspx?result=e2731415-8d2d-4c3f-ba4f-1c1ea167d3ed
# Details.aspx?result=123ccde9-0eb8-48be-9f4f-1bf93e70ac02
# Details.aspx?result=ac13e0c6-7833-4f5b-b3c2-5beeec2bc047
# Details.aspx?result=5801048e-ea74-48fe-9f20-45c8cc654340
# Details.aspx?result=810d84a1-00a5-4b1b-aa8d-e531cf375d1c
# Details.aspx?result=9824ad26-c67b-4610-aaf1-c86e1b060e52
# Details.aspx?result=c5e88939-a4a0-4f2a-97a9-f6374a0f06f9
# Details.aspx?result=d193c077-3460-46c6-8376-39421a6ef2df
# Details.aspx?result=9a7c5a6a-2ea1-417d-8c68-3b0a31a25505
# Details.aspx?result=bbef45c0-caf1-4b99-ab49-ae91d08c89f1
# Details.aspx?result=a001e99d-8470-462c-949c-a0a41ef0e6f7
# Details.aspx?result=48c62119-1d48-40a4-8c97-ad6f02b4e5c1
# Details.aspx?result=90958ad6-21a8-40cb-b746-bb6266a8e2d2
# Details.aspx?result=d6464dbf-1d7b-4bbd-8373-98e36935f8ec
# Details.aspx?result=f8c28f07-1439-44d8-bcec-b736677bd615
# Details.aspx?result=997b60fc-8f38-408e-889e-b33eee9f4355
# Details.aspx?result=59a0ad97-9253-43ff-9e38-ae132fed2d89
# Details.aspx?result=37a1d271-8ae7-4015-8e07-ec21cd5fe879
# Details.aspx?result=575c0dce-7ac7-4f2d-9030-619da7b9896a
# Details.aspx?result=e4c228f6-5b91-4c7b-a842-62fc763fda1f
# Details.aspx?result=a161ca93-41bb-4014-84bb-ee60ccbfda61
# Details.aspx?result=ed6e9aed-466b-4d93-a25c-ba4297b03027
# Details.aspx?result=d1f3d03c-9538-44a6-b821-79882d5f8161
# Details.aspx?result=484f6761-a683-46ba-aeb4-e070bfa4eb1f
# Details.aspx?result=0af1f8aa-74cb-4ef4-8b38-653ed1df4a38
# Details.aspx?result=8434d1e9-8a01-4931-b752-00623d982d5c
# Details.aspx?result=1034f637-c052-4228-8a14-9ef35854e36c
# Details.aspx?result=f1aafadc-34d3-42f6-8b0a-459d15107883
# Details.aspx?result=dc4b1962-7878-4137-bf75-76526c5117ce
# Details.aspx?result=d272d33b-030e-43d2-b348-55a618bad75e
# Details.aspx?result=3eae98ed-ef1d-4712-a6f0-1500b9c9a2e2
# Details.aspx?result=c89d2674-6e3b-435a-9250-33fc871264c9

# %%
# test output of "get_all_links" function and check if we can use "contains" to filter every href

# %%
############################################################################################################################

# %%
pageCount =count_pages()

# %%
pageCount
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9']

# %%
#iterate fetching the res the  pages
all_person =[]
for page in range(len(pageCount)+1):
    print("fetching page "+str(page))
    fetchedData,soup = fetch_next_page(page)
    persons_on_this_page = get_all_links(soup)
    for person in persons_on_this_page:
        print(person)
        each_person = get_person_data(person)
        time.sleep(3)
        all_person.append(each_person)
# Out:
# fetching page 0
# hrefs fethed: 40
# Details.aspx?result=4584690b-c4a0-4e7b-a5f2-a63d1cacc5f5
# Details.aspx?result=68e45791-988a-44ee-89bf-97557b204a42
# Details.aspx?result=f2e7dd5d-cc7d-4217-9433-52ddc728bead
# Details.aspx?result=f0223b49-5368-4507-a7e1-70ad4013ee19
# Details.aspx?result=777bd75b-b77d-434d-8007-61eec1c5e681
# Details.aspx?result=d77cb1c0-73d0-4881-8102-d8043925b835
# Details.aspx?result=13b1247a-8aa1-4cf7-adff-c38cc92113cf
# Details.aspx?result=72a58f0f-1731-48a7-8c8f-6b6a8b56b3ac
# Details.aspx?result=89d0b2b0-2548-4ee2-bf85-9e8759822ad8
# Details.aspx?result=17b084ec-35d3-4eb0-ada4-801429e1a02b
# Details.aspx?result=85781bdf-8e33-4727-af90-83f781f572fc
# Details.aspx?result=d9cd0351-797c-4a22-a800-6e3e4a34c0d9
# Details.aspx?result=a723b993-aba3-47c0-b55e-66592df5cf61
# Details.aspx?result=f2d940f7-39b8-49f8-8c5b-6796b6d11202
# Details.aspx?result=20c9788d-e803-4937-98c3-7ce69004ae33
# Details.aspx?result=c7d93505-ab03-4ea7-871e-43fd0b60172b
# Details.aspx?result=4f15d560-581e-42f5-900a-9e91cdad70d2
# Details.aspx?result=86d002ce-87fc-418e-a9e9-c9047e23ca67
# Details.aspx?result=4b13c034-b6f0-4442-8e1f-c1932b7e826c
# Details.aspx?result=5e8d7b74-f098-4aab-b36b-c86fd831a91c
# Details.aspx?result=41792fdd-78b0-49c7-a772-03b02f9c85fa
# Details.aspx?result=eaed1b67-7313-4a80-aca4-5ab59256a3d0
# Details.aspx?result=e836ff50-2cfc-4d1b-a5be-9058f0cfb7ff
# Details.aspx?result=e379a4db-7a93-4bcc-8e12-5d96f853698d
# Details.aspx?result=ffcbf255-f153-40d9-8dc7-a5aa1a256138
# Details.aspx?result=9878ff11-62ce-480a-8281-07f74048d830
# Details.aspx?result=52189103-257f-4165-b7a1-21d5b05cb9d7
# Details.aspx?result=3e976512-b315-4e34-a4f4-928b04aae3a5
# Details.aspx?result=b7dee468-42f6-49c5-a355-cb220b36d02e
# Details.aspx?result=71e480ad-7a3d-4787-a415-8fc7358ebfe1
# Details.aspx?result=00b40cbe-5eec-493c-bafa-ac2cc58eebd7
# Details.aspx?result=b81d8079-d9c3-4628-ad54-a5385dcf0132
# Details.aspx?result=9332a84f-0804-4a3c-ab20-aee1733b5aab
# Details.aspx?result=a3d66d14-3afb-4df4-8b49-7bbf6c799ab6
# Details.aspx?result=3eb6f6a2-fe8b-4fa7-8a3e-dd12a82ad9fb
# Details.aspx?result=2b665c2c-a2d4-4fc0-9bc6-6a0aa1dc0238
# Details.aspx?result=b63e3dfa-3edb-4e2a-bf78-ace69379d829
# Details.aspx?result=49ba450e-f15a-4b7d-8e6c-d604d766248e
# Details.aspx?result=b789bd85-26b7-4a4f-8d03-f8757fd0bf91
# Details.aspx?result=fbbde816-b504-4228-9f76-ef72afdedc3a
# fetching page 1
# hrefs fethed: 40
# Details.aspx?result=7ea5df5c-4e03-4668-86d4-1849bae1b580
# Details.aspx?result=46361044-1d6f-40fe-a2b8-92d6d288fafc
# Details.aspx?result=83b50193-d7b4-4b55-a927-690f0f3aafda
# Details.aspx?result=b5e804cc-e301-4250-bca6-a0a84bc08047
# Details.aspx?result=26aec926-36fa-4375-9ce2-2447f7a73a42
# Details.aspx?result=7391110c-650b-4885-b9ab-7e3942550859
# Details.aspx?result=0426bffa-5cf2-4fcc-890f-dda18d2d8310
# Details.aspx?result=089cd6c2-6cfd-4193-b769-a00af1cc7331
# Details.aspx?result=e31fb47a-eff4-489f-8169-67bc396dc7d6
# Details.aspx?result=e14a0dab-7a6e-4d2e-ab97-423128390a51
# Details.aspx?result=88cfbc52-a65b-42b4-a232-db646efe603d
# Details.aspx?result=cbff688b-2ab3-4f60-a8d7-39204ed07faf
# Details.aspx?result=2f8b0d23-4509-4ade-9ab3-544a01fbd1aa
# Details.aspx?result=39c1ffa1-c70a-4378-8ac7-dde276a3de7c
# Details.aspx?result=7c5bd9d5-ce79-4c22-b3a9-98b8f5d7ef16
# Details.aspx?result=b903f6db-721e-44ef-870e-95f830d60887
# Details.aspx?result=c547787f-debf-4dc1-84d1-c6ddbd87cdf0
# Details.aspx?result=9b4ffcd4-8828-46a7-83eb-6c88fbf4fd69
# Details.aspx?result=2218fdb8-a009-4490-b94c-1605fca26ef5
# Details.aspx?result=05c66ee2-b196-49b4-acc2-43ce8dd28acd
# Details.aspx?result=e8b513f8-449c-4ead-8c56-9483507cdb5a
# Details.aspx?result=c1f80850-d653-48f5-901f-ecf18a1aed1b
# Details.aspx?result=c6d4d5f9-2b08-4afa-9553-4e8d5d5b050d
# Details.aspx?result=b40d4e3c-7a1c-4ce3-a310-bdddcf57706e
# Details.aspx?result=e08cce55-648a-4788-82a3-e905a515c9ad
# Details.aspx?result=aec6797d-0d99-4e39-aa10-243d784500e6
# Details.aspx?result=a5ea5e40-ccff-4acd-a2a3-18b0ca9afe5a
# Details.aspx?result=97f3350d-2b99-498c-864b-0ee9303db489
# Details.aspx?result=83ac1155-9c9a-4cb9-9d78-b37612485ede
# Details.aspx?result=d968bb5a-af97-432f-8e26-38eacfb9bf71
# Details.aspx?result=97b47f17-851c-45ed-bd36-6299ece6dd39
# Details.aspx?result=96312442-58cf-4524-8409-b2b621f7936d
# Details.aspx?result=6bd6e186-e711-4c6f-b839-fbbbd4b36bcc
# Details.aspx?result=6b67ba31-ca1a-4348-a0fc-55453d88473c
# Details.aspx?result=05344783-7d46-4a51-9559-6ff0249579c5
# Details.aspx?result=54c1b423-0ec8-461a-8241-c9a5e8cea458
# Details.aspx?result=0455502e-9797-4659-954b-5285859e7964
# Details.aspx?result=37c27a08-7b22-4f48-a48d-fceaced23ae5
# Details.aspx?result=31fabc0e-ce01-4d61-a608-dcfdde24d91e
# Details.aspx?result=a81649ba-948d-48a7-b153-1a51f60aeb8f
# fetching page 2
# hrefs fethed: 40
# Details.aspx?result=2f09b77d-b9ba-458d-9dbe-df0319a035d4
# Details.aspx?result=e3f29020-569d-49d0-b2bd-9a234c75451a
# Details.aspx?result=d7771cad-590e-4222-9fc4-61582f675305
# Details.aspx?result=01ce84db-f397-4a54-8faa-1c70f53a8bdb
# Details.aspx?result=373a4a64-4344-42ed-8d67-655f47796b43
# Details.aspx?result=e28282fc-883b-4d55-b07f-9f0527288b94
# Details.aspx?result=f898d971-9d3d-428d-bf70-762017be8f42
# Details.aspx?result=e3565198-f8c8-418a-ba0c-ef6b0cfdf4c4
# Details.aspx?result=95217db9-05c6-4b31-893d-4291e91a46f0
# Details.aspx?result=22cd7957-f7e6-448f-89ab-7e126b04c902
# Details.aspx?result=47ef6340-bb07-4df5-89a5-8f5e6da9a630
# Details.aspx?result=4d98516e-fcdd-4b5a-9f18-dbbeb168e20d
# Details.aspx?result=8049c316-5357-4c52-a674-d2461a70f0f5
# Details.aspx?result=f5aeadb0-6b36-47e1-9673-6e8025e33031
# Details.aspx?result=12eaaf84-5716-4fef-b204-cee5967066f1
# Details.aspx?result=0190318d-f7c9-485e-a87f-1aeebf570aee
# Details.aspx?result=8abc8fdf-4e9f-4d62-baa5-347dbe32e34e
# Details.aspx?result=2d91d034-a781-408f-b529-25ca1a92463a
# Details.aspx?result=8250130b-4626-4261-84a0-b0648c691082
# Details.aspx?result=f8261281-e05a-4cc0-9fc2-b80c400af935
# Details.aspx?result=7bc7ced1-56de-4380-90cd-e8a6515f4017
# Details.aspx?result=b79bebee-5f89-4ead-a9b6-dc0142ae18b0
# Details.aspx?result=b12e0d92-e6b3-4f6b-87b5-7b0c9221f6f6
# Details.aspx?result=00ed2856-ef5f-41d0-80af-e552a7b948e3
# Details.aspx?result=c615cf53-01cb-4fc1-a029-79b4152612b6
# Details.aspx?result=6196e262-a0bf-4257-a8b0-b0e7beeb3167
# Details.aspx?result=c8332c91-be00-48bd-a8be-8ed7b095bcea
# Details.aspx?result=d277cc77-980c-4916-a562-f5859f13b8fa
# Details.aspx?result=96e109f5-3edb-4833-9ade-5fca18c3c6e5
# Details.aspx?result=3c278198-8ed9-4af6-b580-b86c1256044b
# Details.aspx?result=958a15b0-925b-4842-9b20-d222ad7c186b
# Details.aspx?result=7e4d8550-8956-4913-b63a-95f2bef61244
# Details.aspx?result=fbaf4c29-abf2-4a9a-b2ae-cc23aea6e6c9
# Details.aspx?result=f4c145c9-740c-47e0-badc-0a2cba14b2c5
# Details.aspx?result=507d2ec5-8e5a-4d5b-8a32-08b04c790815
# Details.aspx?result=04d1fdce-fb4b-48fe-af98-b0bd07307a1d
# Details.aspx?result=bf7299a8-1917-44bc-b1f4-cedab111bb03
# Details.aspx?result=0fdfce8a-ee36-4fb6-bd41-dc602f77ede7
# Details.aspx?result=a9e340c5-093c-4f56-acf8-59048c407d4c
# Details.aspx?result=113d1a78-b275-477a-a7a2-ea9d1ee5d4e1
# fetching page 3
# hrefs fethed: 40
# Details.aspx?result=2b15e7f9-d0ee-46a4-ad79-f0e12c24ee31
# Details.aspx?result=85e60dd2-3d54-4ecd-9b72-4f7d83b28dba
# Details.aspx?result=917a3982-231d-4104-9dd7-7f59b712d8cc
# Details.aspx?result=31a25793-ff89-445c-825f-f4fdf9f70b7c
# Details.aspx?result=254967fb-4fee-4232-97ba-cab095635e42
# Details.aspx?result=5037adb0-8045-47f0-917a-219d57b1d8b1
# Details.aspx?result=d9298b45-7a8c-49ca-a095-c26d7b310516
# Details.aspx?result=8cac8d00-31b1-44fc-b546-d35b0f5dcb5c
# Details.aspx?result=f491f2fe-e547-46cc-b238-fde0cbc69010
# Details.aspx?result=718d43cc-fd4c-4ae0-b254-575d2c8da0af
# Details.aspx?result=ac5c1b06-2fa3-4c5e-96f7-58c26a64a6e1
# Details.aspx?result=6f8875cc-e0de-4109-ba59-59c0c54ff3d0
# Details.aspx?result=470a28a2-7493-4957-b6c9-2aecc16ef105
# Details.aspx?result=34aa7099-1456-4698-ac86-08ca75cff291
# Details.aspx?result=84c89d04-5885-4a82-9ed4-d9c62e15ffca
# Details.aspx?result=f41b14e4-ac91-41ea-a11b-d8d0ad697786
# Details.aspx?result=5c967238-99e8-4988-b90e-a5b718e384a0
# Details.aspx?result=b8e36e01-f2f0-4061-ba0e-8d0d7013d7cf
# Details.aspx?result=dfc0d9fd-a0a4-4856-bc3b-86393fe86d84
# Details.aspx?result=a5226949-4dfa-425c-8e3d-44f927b58b0b
# Details.aspx?result=fc21c6e5-0973-4b6a-8e1a-6ba6fd22c124
# Details.aspx?result=bee098c6-9c47-4b4d-bab5-cc5ea289a3bf
# Details.aspx?result=43289b70-d89c-4fd5-97ac-39fafed07deb
# Details.aspx?result=9a30aa90-44b5-4e1f-a83a-edcfbb1a122a
# Details.aspx?result=fc7970fc-96e7-4386-9967-ebf7830cb013
# Details.aspx?result=a41c65b4-4129-4275-8fd0-55ff99c2c26b
# Details.aspx?result=b49e2d0c-48e8-4220-9efb-777c21b2d19a
# Details.aspx?result=5430bccc-6589-4c04-9978-8b4cc563da96
# Details.aspx?result=27da7f96-241f-4774-8b1f-c5e1011d0828
# Details.aspx?result=af3ae567-a945-4be0-b310-73b1eb9f00ec
# Details.aspx?result=89b943d5-c627-4c24-86b7-f945602848c9
# Details.aspx?result=6084fc2c-ca5a-41f3-b3d1-d87d1990af66
# Details.aspx?result=5af16f9e-c5b3-4ae9-bc24-829c55024549
# Details.aspx?result=91268f3f-ba81-42e8-8335-f8eb7f6098c3
# Details.aspx?result=ff2bb3f6-7b01-46bc-9bcf-620921ad4602
# Details.aspx?result=0b63b9d5-f77f-48de-9897-951933b8adb8
# Details.aspx?result=bb3d1226-c8f8-43b3-b47f-0256026663e1
# Details.aspx?result=304974a5-3f2b-4b0e-9de0-3a53b2655017
# Details.aspx?result=722d700f-2545-48bd-96db-9a6e21314e9f
# Details.aspx?result=27872ed7-78e2-426d-8162-5be46e8c9c6f
# fetching page 4
# hrefs fethed: 40
# Details.aspx?result=3d9a2cc3-6e71-4a90-ad85-6a1b1eec1b54
# Details.aspx?result=486acdd0-d7ed-4552-827a-43b06d426bbc
# Details.aspx?result=17ff0624-ad8e-4815-bc1a-da844d69046c
# Details.aspx?result=4588e093-86e4-402b-bbd0-936380520968
# Details.aspx?result=452a9315-2559-4bd2-a9ae-0df4e802c028
# Details.aspx?result=a5cfbea7-7a06-4dc2-9de3-d1c750fe2d53
# Details.aspx?result=053545d1-dbdb-4fb6-8322-2b157584f394
# Details.aspx?result=72541b15-3369-4c59-aabe-e8cef7c87a48
# Details.aspx?result=427a9bf0-de33-4707-96fb-a7d4b631e5ff
# Details.aspx?result=2a6b9440-9c6b-46ca-9cdd-732a20ec3897
# Details.aspx?result=3d1dafd4-faf2-40d8-8dc5-8ba72808d27a
# Details.aspx?result=19b902f0-e6c4-4a93-95fa-3e06700c143b
# Details.aspx?result=a93cd0a4-a32c-4eeb-b68b-854a78d340f2
# Details.aspx?result=55159cff-67dc-4d19-9e4c-a87e59b59517
# Details.aspx?result=1f5841c7-9afa-47fe-8d6e-89adfb1c842a
# Details.aspx?result=c671830d-8313-4d95-84bb-97c28fe47f83
# Details.aspx?result=b43cf830-f1c6-431d-b374-b9f700f9c8ab
# Details.aspx?result=e94ce6c8-0380-4bf8-94ee-67dea3b2d741
# Details.aspx?result=78f38041-0ae4-44c8-a34b-7396c4cf8b8d
# Details.aspx?result=c52a7c4d-3954-4218-88b8-de2dd95eedf6
# Details.aspx?result=ec7748a4-9398-4806-8a61-1996a441aaab
# Details.aspx?result=2dfda6b9-0fd2-495a-9bc0-9a0631f077df
# Details.aspx?result=ec813210-b81d-41be-a61a-44616db7e6b8
# Details.aspx?result=f3e44e56-bf15-4956-aa15-76be0ed9f858
# Details.aspx?result=5e11c8ba-f130-4ea8-9da4-e942a42285ca
# Details.aspx?result=2a8a29f5-19a6-4a4f-b265-832110d5b37f
# Details.aspx?result=ab987ed0-6e6e-43bc-be36-1768e1eea7e8
# Details.aspx?result=2a55de0c-4fc2-47b6-9d5c-817ce203d39d
# Details.aspx?result=89231023-1341-437d-8e23-8efb6027999f
# Details.aspx?result=8b77750c-e9b5-4061-9e4b-2a3ffddd5fb0
# Details.aspx?result=2f40090e-3a99-4fe4-85c7-3c0525c5d6b0
# Details.aspx?result=ae753188-49fc-4a4d-b2c1-3c7e9437030c
# Details.aspx?result=637c487e-f971-4d31-ae49-43ed803917af
# Details.aspx?result=67209cbd-2bd2-4218-b535-0c4059487a2e
# Details.aspx?result=82ece52c-c3f5-4175-b925-d56fccdf2258
# Details.aspx?result=d24a6850-1b15-4061-b5e6-1429f3d30fc5
# Details.aspx?result=6740f91b-6849-48df-ba6f-ef5442ffef36
# Details.aspx?result=06a46fc9-c6f2-4d9e-b838-e6434c3ce696
# Details.aspx?result=6960a43a-1f39-4f7c-ae5e-86496474c8a2
# Details.aspx?result=2421e30d-7482-4ee1-8368-7b5b43b3714d
# fetching page 5
# hrefs fethed: 40
# Details.aspx?result=278c25c5-92e5-418a-89e4-0999315ea50b
# Details.aspx?result=eb0ec30a-abea-4c3b-a356-20975a0c224b
# Details.aspx?result=81bddac1-237d-44d1-ac46-110819dfe03c
# Details.aspx?result=5a20b796-1be2-4357-a374-e8f687838e92
# Details.aspx?result=25d1daf1-1cb9-44d8-b75e-beb9608befae
# Details.aspx?result=a9c1a796-7766-419c-9734-b99905e2fe60
# Details.aspx?result=b5c33f68-5f8d-4883-bd64-3d918d4bb123
# Details.aspx?result=376eb874-ea0f-464e-aa4e-43cc2ef2ea04
# Details.aspx?result=4d915f99-3c10-410d-8595-ebb991b57644
# Details.aspx?result=2ad47331-9b2e-4afb-9b31-050fe82d057e
# Details.aspx?result=2e5dd313-f4f8-4227-801c-30bbae0f92db
# Details.aspx?result=f6897b41-fbb7-4405-89cd-e923b77d88cd
# Details.aspx?result=ca391b87-4b5e-40d7-a1cf-a42fc50207cc
# Details.aspx?result=6df61692-c6a1-4768-b44f-491184afab7d
# Details.aspx?result=bcf20dd6-97f3-4b59-9ce3-740273477511
# Details.aspx?result=498007d0-51e4-410e-8a9e-ac4539ad97a1
# Details.aspx?result=803d0fd9-5fa6-4e28-a042-856a4b1fb857
# Details.aspx?result=a566a602-7bc5-4727-8576-33f85f84b1c1
# Details.aspx?result=81edde95-f48c-4306-b254-d121eb975f5a
# Details.aspx?result=26d76e5e-74a1-40b9-86a7-d8c1d97c0d87
# Details.aspx?result=9e8df350-ce88-402d-8a76-659dfac1d6cb
# Details.aspx?result=ec677f7a-8aee-4236-8a3d-ed946a8f7fa9
# Details.aspx?result=3eb817f3-8af0-4f63-b827-5fd63440a5fb
# Details.aspx?result=752b7f7e-f4a6-48e8-b9da-61bb96d6deb8
# Details.aspx?result=4ff89953-c608-4163-9f17-d5b882e9dbee
# Details.aspx?result=9e9959c6-3288-424d-ba35-7f513e59a395
# Details.aspx?result=97a7db75-d41a-486e-a1b0-3404ef28297f
# Details.aspx?result=5a808406-d195-44cb-b711-0f017d934548
# Details.aspx?result=85a8726d-cf8d-4ab0-bc43-58907d123358
# Details.aspx?result=9c7f7be4-4744-414e-9450-164fc0170967
# Details.aspx?result=be21460f-be37-4a63-8742-61a7421b8051
# Details.aspx?result=0c2356e9-2149-45de-b9c3-3501419810bd
# Details.aspx?result=da364374-79da-4d63-92ef-a88d7961d69a
# Details.aspx?result=0775a363-a07c-4ec8-918a-e796f2d89b86
# Details.aspx?result=15a1d803-0303-47c4-aca2-d03978cc7cd4
# Details.aspx?result=9bd198af-d045-41ea-b7a8-b93a15f6ebb4
# Details.aspx?result=7faa700f-3eb1-402e-9876-bbe782ae941f
# Details.aspx?result=7534aeb7-65aa-4591-81fe-b0cf6757036f
# Details.aspx?result=3fe57250-f10e-4560-9c1b-09a6daaf05cf
# Details.aspx?result=35929ab8-ef0b-4b51-b87e-13f65d0e2cd4
# fetching page 6
# hrefs fethed: 40
# Details.aspx?result=da16fb81-7751-4dae-ae13-c7fcbc7e8ed2
# Details.aspx?result=4b7ffea2-aef3-4b27-a96d-8026ebf5b7e8
# Details.aspx?result=bb734e9f-68a1-49ec-bdfd-88eab2d18eac
# Details.aspx?result=952d8606-d3fe-48ad-b148-d3f2d7cafe42
# Details.aspx?result=b7f5ee06-eb3d-412d-9727-5b57d4ce4a19
# Details.aspx?result=136d9a95-9dde-4b65-aa35-4d4b13d96fae
# Details.aspx?result=7461c5e2-21ca-4aa4-a8bb-2479e3896546
# Details.aspx?result=97ada855-144b-4b14-b41b-c035d6b7d57b
# Details.aspx?result=19c669e0-b1c9-4ca3-b200-13e3d09a9b1d
# Details.aspx?result=9fcde98a-5387-4261-a88c-83b3168c52e8
# Details.aspx?result=d2e829d3-c242-4b25-92c7-c061b85661ab
# Details.aspx?result=7d4ddbb0-8b39-461e-ba4f-10c0a583463e
# Details.aspx?result=9b90d7ed-eacb-41ba-8989-cd55bc5b453d
# Details.aspx?result=ef69f7a5-8bc9-4120-a6a0-d0440b868bf4
# Details.aspx?result=0923f4e0-5c23-4f84-af70-2271d7ca4a68
# Details.aspx?result=41c55492-461a-4eae-990d-ecddd2fdbdc5
# Details.aspx?result=f8c89aae-9d24-498f-a5c7-5382f173190f
# Details.aspx?result=7e2acf0a-8a4a-40e5-b949-c994695bcecd
# Details.aspx?result=932850c1-0783-43ef-ac8a-20a42a686b84
# Details.aspx?result=c7eff113-db6a-48c3-bcc0-3f80c2c9fb6d
# Details.aspx?result=aaf94698-8932-4f0e-9e17-6fdfec42424f
# Details.aspx?result=4a24ed4c-abe7-408a-88bb-98a128631f3c
# Details.aspx?result=425fcb56-68fc-49b5-ac11-92649443fbd5
# Details.aspx?result=60377d71-c87c-4d52-aad1-3a23be6508cb
# Details.aspx?result=461ac3d4-6732-4959-a325-40d516194cbf
# Details.aspx?result=cd96511f-60d1-49fb-830b-f8962aa3cdaa
# Details.aspx?result=82ebeb0b-6652-4c5e-b207-8a2886b1a51b
# Details.aspx?result=064e0ccf-415c-482f-ba95-4858b13c7795
# Details.aspx?result=4b55cd24-f133-4df2-a7e7-4b8ff0b4b5f1
# Details.aspx?result=9c33cc3b-86e2-4c9d-8a59-c9e1fd491138
# Details.aspx?result=8a3ff451-294e-466b-9a7d-0e0ef3b31ca6
# Details.aspx?result=54839b25-93fe-4b42-bf38-e8f715814a8e
# Details.aspx?result=a80ecef8-dfe7-4f60-9f60-fbea150bc2c7
# Details.aspx?result=df934ecc-1c5b-4ab1-8792-fa1dd3e05bb0
# Details.aspx?result=727e9c3a-748f-46bb-8d59-758dfb18cd99
# Details.aspx?result=7151dd64-d256-4d84-b889-82028181f780
# Details.aspx?result=7d0225dd-e339-4ce7-aa6f-3a08fc17ba1c
# Details.aspx?result=7ab73116-9c6b-43ec-93ea-b3192f1cc88d
# Details.aspx?result=1ab94a1d-299f-46fe-af7d-a2f6ecebd007
# Details.aspx?result=22003eea-b8b4-4443-8cda-35ce0a98bd3f
# fetching page 7
# hrefs fethed: 40
# Details.aspx?result=8a0e7812-d480-48c9-8aba-67029190fca0
# Details.aspx?result=6377d3c5-1bab-4acf-b9c3-cadd36808a35
# Details.aspx?result=86d69f8f-d142-4141-910d-1ab9412f30e1
# Details.aspx?result=d17883d1-efe3-46e2-8df1-77d9a67eb59e
# Details.aspx?result=dadd2d50-59c4-436c-835e-1f10a791d1e3
# Details.aspx?result=cb1626fd-8ea6-482a-aed8-0c09171bc3b8
# Details.aspx?result=9893b11b-af81-4eb7-9179-16d14a8ca059
# Details.aspx?result=a0804821-dbae-4b92-9ac4-e85f34d5fbd3
# Details.aspx?result=ae3c553e-3197-4e7f-b461-636d106fa868
# Details.aspx?result=a5f23ba0-761a-462b-9a72-43ba52ba8647
# Details.aspx?result=fa23e635-3c00-4c48-8140-9f0a545d05c5
# Details.aspx?result=c15fee39-7cf3-49d1-b64c-8a8fa01f58ea
# Details.aspx?result=ecacbbee-e592-4e06-87ba-8fe38f33ac5b
# Details.aspx?result=3169452c-0793-41c0-b439-312cc47ce87b
# Details.aspx?result=21a64ca3-ad1a-413e-a017-9bf289505aa5
# Details.aspx?result=c357d9b6-e42d-4f54-a5c4-072919519048
# Details.aspx?result=3871efb7-a812-4055-b2fb-37aab531eef1
# Details.aspx?result=64789806-972b-44aa-803a-e5998725b56b
# Details.aspx?result=7165adb9-3425-40b0-921f-cbe77c734bef
# Details.aspx?result=098ec328-5336-48ab-8eec-c8a1f1955146
# Details.aspx?result=5c8d573b-c701-45fc-8b3b-996771b6cd14
# Details.aspx?result=c30df16f-bc4e-450a-905f-82ae29b648dd
# Details.aspx?result=634c6651-cc0c-4f64-8e50-b82874999422
# Details.aspx?result=981ed6a6-f903-49d1-a388-a143c4774d63
# Details.aspx?result=ef2222c8-d594-4c36-add0-7728fc48bd33
# Details.aspx?result=59ee8520-30a5-48ee-bae6-97d792ce9882
# Details.aspx?result=02d9fcf4-6e0e-4cb5-9f9d-cc89034eb78d
# Details.aspx?result=1637c605-90ba-44d0-81bf-d0509a73682a
# Details.aspx?result=6571946b-125b-4c62-a5f7-03f62f3786f4
# Details.aspx?result=f06a8549-3b29-486c-b11e-a9636beebec8
# Details.aspx?result=df025ab3-8488-4d81-9298-9631553a2383
# Details.aspx?result=175c54fb-a43f-4939-b420-270e070f9fe5
# Details.aspx?result=8539630f-cb69-4588-b192-80439c9ae66e
# Details.aspx?result=d20cb600-3cc2-442e-bdcf-f262987ab6da
# Details.aspx?result=68ba57b4-29b0-4c8a-be76-2bbcc0e8470e
# Details.aspx?result=de06867f-9cc2-4481-8ed1-c943b37462cd
# Details.aspx?result=295257a6-4bab-4481-8211-0c8561b1faf8
# Details.aspx?result=7b44fb46-6745-4fac-bb30-01186daac119
# Details.aspx?result=b21b2fd7-bef9-48c3-ade9-626ec4b7e3a8
# Details.aspx?result=3f8bbd95-356c-4769-9897-71bcc39a2db7
# fetching page 8
# hrefs fethed: 20
# Details.aspx?result=4df755b1-0f68-4e58-80d3-518f01a32a5b
# Details.aspx?result=0db999bf-ae51-46e3-9bf8-80835c67512b
# Details.aspx?result=a7e3e9b0-3a7c-4606-aee6-883ecb9a5688
# Details.aspx?result=95b5e427-e3e0-43a0-aee1-19ed88a6df9e
# Details.aspx?result=2dc4676a-9f53-4434-a7de-dc82d9e509b7
# Details.aspx?result=baad3e33-eb10-4168-9eaa-94d5cb073941
# Details.aspx?result=2000864f-5323-4b7c-a00e-2f71392738f7
# Details.aspx?result=0f9df03a-4e38-4994-b822-5f8de4249477
# Details.aspx?result=ac60516c-80eb-456c-9510-fc390c9dd59f
# Details.aspx?result=589cb8d5-a068-4b07-a056-51c33eb31ef2
# Details.aspx?result=537d6ddf-f149-439f-b0ba-962e9f2ee5ea
# Details.aspx?result=be6bf1e2-751c-4548-9da0-3abba4b5ac38
# Details.aspx?result=a6507e33-4340-4b8e-802b-04d5e119c7fc
# Details.aspx?result=03e64e50-c19b-4ac5-bc74-34c0123bc098
# Details.aspx?result=ea40d3ec-1cc7-4609-8a71-1e33ee5cbdda
# Details.aspx?result=4ca3902f-62e8-440b-9793-70a7b1de7398
# Details.aspx?result=3ac58745-6659-406a-b019-fd2126977146
# Details.aspx?result=1d0dcd13-ce5f-49f6-b903-143df9c4b9f9
# Details.aspx?result=fed3c01f-ab3c-488f-abcd-86c809484b08
# Details.aspx?result=821f968a-e710-4adf-a1ea-27c8cab412a9

# %%
final_data = pd.concat(all_person)

# %%
final_data
# Out:
# 0   First:  Middle:    Last:      DBA: Lic #:       Type:  Status:  \
# 0    Abbie  Anh-Buu       La            P8571  Pharmacist  Expired
# 0    JAMES     PAUL  LABELLA            P7148  Pharmacist   Active
# 0   KEATEN  PATRICK   LABREL            P7351  Pharmacist  Expired
# 0      ROY   ARTHUR    LACEY            P7222  Pharmacist  Expired
# 0     JEFF        A  LACHELT            P5376  Pharmacist   Active
# ..     ...      ...      ...       ...    ...         ...      ...
# 0     MARY        J    LYONS            P5213  Pharmacist   Active
# 0      TOM             LYONS            P3049  Pharmacist  Expired
# 0     ALEX    JAMES  LYSTRUP            P8065  Pharmacist   Active
# 0     RYAN        F    LYTLE            P6435  Pharmacist   Active
# 0     Sora               Lyu  Sora Lyu  P8855  Pharmacist   Active
#
# 0  Orig. Issued Date:     Expiry:  Effective:    Status Reason: Status Date:  \
# 0          10/10/2019   4/30/2020  10/10/2019           Expired    6/25/2020
# 0           9/18/2014  12/31/2023   9/18/2014                       7/1/2018
# 0            8/5/2015   6/30/2016    8/5/2015                       8/5/2015
# 0           2/17/2015   6/30/2019    7/1/2018           Expired     7/1/2019
# 0           5/21/2002  11/30/2023   5/21/2002                       7/1/2018
# ..                ...         ...         ...               ...          ...
# 0           5/23/2002   2/29/2024   5/23/2002                       7/1/2018
# 0           5/15/2002   6/30/2011   5/18/2010                      5/18/2010
# 0           7/12/2018  12/31/2023   7/12/2018   License Renewal     1/8/2019
# 0           7/21/2010   5/31/2023   7/21/2010                       7/1/2018
# 0           6/17/2020   4/30/2023   6/17/2020  License Issuance    6/17/2020
#
# 0     Renewed:      Method:
# 0               Application
# 0   10/26/2022  Reciprocity
# 0     8/5/2015  Application
# 0     7/1/2018  Reciprocity
# 0    10/6/2022  Application
# ..         ...          ...
# 0     1/2/2023  Application
# 0    5/18/2010  Application
# 0   11/28/2022  Application
# 0    5/16/2022  Application
# 0    3/31/2022  Reciprocity
#
# [340 rows x 14 columns]

# %%
#  retain the selected columns
final_data.drop(['DBA:', 'Effective:','Status Reason:','Status Date:','Method:'], axis=1)
# Out:
# 0   First:  Middle:    Last: Lic #:       Type:  Status: Orig. Issued Date:  \
# 0    Abbie  Anh-Buu       La  P8571  Pharmacist  Expired         10/10/2019
# 0    JAMES     PAUL  LABELLA  P7148  Pharmacist   Active          9/18/2014
# 0   KEATEN  PATRICK   LABREL  P7351  Pharmacist  Expired           8/5/2015
# 0      ROY   ARTHUR    LACEY  P7222  Pharmacist  Expired          2/17/2015
# 0     JEFF        A  LACHELT  P5376  Pharmacist   Active          5/21/2002
# ..     ...      ...      ...    ...         ...      ...                ...
# 0     MARY        J    LYONS  P5213  Pharmacist   Active          5/23/2002
# 0      TOM             LYONS  P3049  Pharmacist  Expired          5/15/2002
# 0     ALEX    JAMES  LYSTRUP  P8065  Pharmacist   Active          7/12/2018
# 0     RYAN        F    LYTLE  P6435  Pharmacist   Active          7/21/2010
# 0     Sora               Lyu  P8855  Pharmacist   Active          6/17/2020
#
# 0      Expiry:    Renewed:
# 0    4/30/2020
# 0   12/31/2023  10/26/2022
# 0    6/30/2016    8/5/2015
# 0    6/30/2019    7/1/2018
# 0   11/30/2023   10/6/2022
# ..         ...         ...
# 0    2/29/2024    1/2/2023
# 0    6/30/2011   5/18/2010
# 0   12/31/2023  11/28/2022
# 0    5/31/2023   5/16/2022
# 0    4/30/2023   3/31/2022
#
# [340 rows x 9 columns]

# %%
print("saving file")
filepath = Path(save_loc)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
final_list.to_csv(filepath)
# Out:
# saving file
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\Triple_One\Anaconda3\lib\pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1250         try:
# -> 1251             self._accessor.mkdir(self, mode)
#    1252         except FileNotFoundError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\rsimon\\Desktop'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-32-711806da67eb> in <module>
#       1 print("saving file")
#       2 filepath = Path(save_loc)
# ----> 3 filepath.parent.mkdir(parents=True, exist_ok=True)
#       4 final_list.to_csv(filepath)
#
# C:\Users\Triple_One\Anaconda3\lib\pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1253             if not parents or self.parent == self:
#    1254                 raise
# -> 1255             self.parent.mkdir(parents=True, exist_ok=True)
#    1256             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1257         except OSError:
#
# C:\Users\Triple_One\Anaconda3\lib\pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1249             self._raise_closed()
#    1250         try:
# -> 1251             self._accessor.mkdir(self, mode)
#    1252         except FileNotFoundError:
#    1253             if not parents or self.parent == self:
#
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\rsimon'

# %%
print("scrape completed")
